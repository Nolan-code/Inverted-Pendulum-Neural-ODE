# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# #Model

# %%
class MLP_T(nn.Module):
  def __init__(self):
    super().__init__()

    self.net = nn.Sequential(
        nn.Linear(1,128),
        nn.Tanh(),
        nn.Linear(128,128),
        nn.Tanh(),
        nn.Linear(128,1)
    )

  def forward(self,x):
    return self.net(x)

class MLP_V(nn.Module):
  def __init__(self):
    super().__init__()

    self.net = nn.Sequential(
        nn.Linear(2,128),
        nn.Tanh(),
        nn.Linear(128,128),
        nn.Tanh(),
        nn.Linear(128,1)
    )

  def forward(self,x):
    return self.net(x)

class HNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.T = MLP_T()  # entrée: ω
        self.V = MLP_V()  # entrée: sinθ, cosθ

    def forward(self, X):
        sinθ, cosθ, ω = X[:,0], X[:,1], X[:,2]
        T = self.T(ω.unsqueeze(1))
        V = self.V(torch.stack([sinθ, cosθ], dim=1))
        return T + V

# %% [markdown]
# #Training Loop

# %%
def hamiltonian_dynamics(model, X_tilde, theta):
    X_tilde = X_tilde.requires_grad_(True)
    H = model(X_tilde).sum()

    grad = torch.autograd.grad(H, X_tilde, create_graph=True)[0]

    dH_dsin = grad[:,0]
    dH_dcos = grad[:,1]
    dH_dw   = grad[:,2]

    dH_dtheta = dH_dsin * torch.cos(theta) - dH_dcos * torch.sin(theta)

    dtheta = dH_dw
    domega = -dH_dtheta

    return dtheta, domega

# %%
#-------------
# Load data
#-------------

data = np.load("4.5_HNN_dataset.npz")
split = np.load("4.6_splits_HNN.npz")

X = np.hstack(data["X"])
X = X.reshape(15300, 2)
Y = data["Y"]
Y = Y.reshape(15300, 2)
print(X.shape)
print(Y.shape)

#----------------
# Split data
#----------------

X_train = X[split["train_idx"]]
Y_train = Y[split["train_idx"]]

X_test = X[split["test_idx"]]
Y_test = Y[split["test_idx"]]

#-------------------
# Convert to tensor
#-------------------

X_train = torch.tensor(X_train, dtype=torch.float32)
Y_train = torch.tensor(Y_train, dtype=torch.float32)

X_test = torch.tensor(X_test, dtype=torch.float32)
Y_test = torch.tensor(Y_test, dtype=torch.float32)

train_dataset = TensorDataset(X_train, Y_train)
test_dataset = TensorDataset(X_test, Y_test)

train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False)

#---------
#  Model
#---------

model = HNN()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
loss_fn = nn.MSELoss()
λ1 = 0.1
λ2 = 0.1
#----------------
# Training loop
#----------------

n_epochs = 350

for epoch in range(n_epochs):
  model.train()
  train_loss = 0.0

  for X_batch, Y_batch in train_loader:

    theta = X_batch[:, 0]
    omega = X_batch[:, 1]

    X_tilde = torch.stack([
        torch.sin(theta),
        torch.cos(theta),
        omega
    ], dim=1)

    dtheta_pred, domega_pred = hamiltonian_dynamics(
        model, X_tilde, theta
    )

    theta_eq = torch.tensor([np.pi], requires_grad=True)
    omega_eq = torch.tensor([0.0])

    x_eq = torch.stack([
        torch.sin(theta_eq),
        torch.cos(theta_eq),
        omega_eq
    ], dim=1)

    H_eq = model(x_eq)

    grad_eq = torch.autograd.grad(
       H_eq,
       x_eq,
       create_graph=True
    )[0]

    loss_eq = grad_eq.pow(2).sum()

    grad_eq_scalar = torch.sum(grad_eq)
    grad2 = torch.autograd.grad(grad_eq_scalar, theta_eq, create_graph=True)[0]
    loss_eq_hessian = torch.relu(-grad2).sum()

    loss = (
        loss_fn(dtheta_pred, Y_batch[:,0]) +
        loss_fn(domega_pred, Y_batch[:,1]) +
        λ1 * loss_eq +
        λ2 * loss_eq_hessian
    )

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()


    train_loss += loss.item()

  train_loss /= len(train_loader)


  model.eval()
  test_loss = 0.0

  for X_batch, Y_batch in test_loader:
      theta = X_batch[:,0]
      omega = X_batch[:,1]

      X_tilde = torch.stack([
        torch.sin(theta),
        torch.cos(theta),
        omega
      ], dim=1)

      dtheta_pred, domega_pred = hamiltonian_dynamics(
        model, X_tilde, theta
      )

      loss = (
        loss_fn(dtheta_pred, Y_batch[:,0]) +
        loss_fn(domega_pred, Y_batch[:,1])
      )
      test_loss += loss.item()

  test_loss /= len(test_loader)
  print(f"Epoch {epoch+1}/{n_epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}")

#-------------
# Save model
#-------------

torch.save(model.state_dict(), "Upgrade_HNN_v2.pth")
# Out:
# (15300, 2)
# (15300, 2)
# Epoch 1/350, Train Loss: 22.8925, Test Loss: 7.3882
# Epoch 2/350, Train Loss: 4.3175, Test Loss: 1.4010
# Epoch 3/350, Train Loss: 1.2095, Test Loss: 0.3259
# Epoch 4/350, Train Loss: 0.4646, Test Loss: 0.1213
# Epoch 5/350, Train Loss: 0.2021, Test Loss: 0.0674
# Epoch 6/350, Train Loss: 0.0724, Test Loss: 0.0375
# Epoch 7/350, Train Loss: 0.0312, Test Loss: 0.0225
# Epoch 8/350, Train Loss: 0.0194, Test Loss: 0.0155
# Epoch 9/350, Train Loss: 0.0138, Test Loss: 0.0116
# Epoch 10/350, Train Loss: 0.0102, Test Loss: 0.0088
# Epoch 11/350, Train Loss: 0.0080, Test Loss: 0.0069
# Epoch 12/350, Train Loss: 0.0063, Test Loss: 0.0057
# Epoch 13/350, Train Loss: 0.0051, Test Loss: 0.0049
# Epoch 14/350, Train Loss: 0.0044, Test Loss: 0.0040
# Epoch 15/350, Train Loss: 0.0035, Test Loss: 0.0032
# Epoch 16/350, Train Loss: 0.0031, Test Loss: 0.0028
# Epoch 17/350, Train Loss: 0.0026, Test Loss: 0.0025
# Epoch 18/350, Train Loss: 0.0022, Test Loss: 0.0020
# Epoch 19/350, Train Loss: 0.0020, Test Loss: 0.0019
# Epoch 20/350, Train Loss: 0.0017, Test Loss: 0.0015
# Epoch 21/350, Train Loss: 0.0015, Test Loss: 0.0015
# Epoch 22/350, Train Loss: 0.0014, Test Loss: 0.0013
# Epoch 23/350, Train Loss: 0.0012, Test Loss: 0.0012
# Epoch 24/350, Train Loss: 0.0010, Test Loss: 0.0010
# Epoch 25/350, Train Loss: 0.0009, Test Loss: 0.0009
# Epoch 26/350, Train Loss: 0.0008, Test Loss: 0.0008
# Epoch 27/350, Train Loss: 0.0008, Test Loss: 0.0010
# Epoch 28/350, Train Loss: 0.0008, Test Loss: 0.0007
# Epoch 29/350, Train Loss: 0.0007, Test Loss: 0.0007
# Epoch 30/350, Train Loss: 0.0006, Test Loss: 0.0006
# Epoch 31/350, Train Loss: 0.0005, Test Loss: 0.0005
# Epoch 32/350, Train Loss: 0.0005, Test Loss: 0.0005
# Epoch 33/350, Train Loss: 0.0005, Test Loss: 0.0004
# Epoch 34/350, Train Loss: 0.0004, Test Loss: 0.0004
# Epoch 35/350, Train Loss: 0.0004, Test Loss: 0.0006
# Epoch 36/350, Train Loss: 0.0004, Test Loss: 0.0003
# Epoch 37/350, Train Loss: 0.0003, Test Loss: 0.0003
# Epoch 38/350, Train Loss: 0.0003, Test Loss: 0.0003
# Epoch 39/350, Train Loss: 0.0003, Test Loss: 0.0003
# Epoch 40/350, Train Loss: 0.0003, Test Loss: 0.0003
# Epoch 41/350, Train Loss: 0.0003, Test Loss: 0.0003
# Epoch 42/350, Train Loss: 0.0003, Test Loss: 0.0002
# Epoch 43/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 44/350, Train Loss: 0.0003, Test Loss: 0.0002
# Epoch 45/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 46/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 47/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 48/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 49/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 50/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 51/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 52/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 53/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 54/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 55/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 56/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 57/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 58/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 59/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 60/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 61/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 62/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 63/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 64/350, Train Loss: 0.0002, Test Loss: 0.0004
# Epoch 65/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 66/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 67/350, Train Loss: 0.0001, Test Loss: 0.0002
# Epoch 68/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 69/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 70/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 71/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 72/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 73/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 74/350, Train Loss: 0.0003, Test Loss: 0.0002
# Epoch 75/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 76/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 77/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 78/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 79/350, Train Loss: 0.0001, Test Loss: 0.0002
# Epoch 80/350, Train Loss: 0.0002, Test Loss: 0.0000
# Epoch 81/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 82/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 83/350, Train Loss: 0.0004, Test Loss: 0.0006
# Epoch 84/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 85/350, Train Loss: 0.0001, Test Loss: 0.0002
# Epoch 86/350, Train Loss: 0.0001, Test Loss: 0.0002
# Epoch 87/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 88/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 89/350, Train Loss: 0.0003, Test Loss: 0.0002
# Epoch 90/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 91/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 92/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 93/350, Train Loss: 0.0001, Test Loss: 0.0005
# Epoch 94/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 95/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 96/350, Train Loss: 0.0006, Test Loss: 0.0001
# Epoch 97/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 98/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 99/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 100/350, Train Loss: 0.0002, Test Loss: 0.0004
# Epoch 101/350, Train Loss: 0.0001, Test Loss: 0.0003
# Epoch 102/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 103/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 104/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 105/350, Train Loss: 0.0003, Test Loss: 0.0002
# Epoch 106/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 107/350, Train Loss: 0.0003, Test Loss: 0.0003
# Epoch 108/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 109/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 110/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 111/350, Train Loss: 0.0003, Test Loss: 0.0000
# Epoch 112/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 113/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 114/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 115/350, Train Loss: 0.0000, Test Loss: 0.0001
# Epoch 116/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 117/350, Train Loss: 0.0002, Test Loss: 0.0003
# Epoch 118/350, Train Loss: 0.0002, Test Loss: 0.0000
# Epoch 119/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 120/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 121/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 122/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 123/350, Train Loss: 0.0001, Test Loss: 0.0002
# Epoch 124/350, Train Loss: 0.0006, Test Loss: 0.0009
# Epoch 125/350, Train Loss: 0.0004, Test Loss: 0.0002
# Epoch 126/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 127/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 128/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 129/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 130/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 131/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 132/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 133/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 134/350, Train Loss: 0.0003, Test Loss: 0.0002
# Epoch 135/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 136/350, Train Loss: 0.0003, Test Loss: 0.0002
# Epoch 137/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 138/350, Train Loss: 0.0001, Test Loss: 0.0005
# Epoch 139/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 140/350, Train Loss: 0.0009, Test Loss: 0.0002
# Epoch 141/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 142/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 143/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 144/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 145/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 146/350, Train Loss: 0.0001, Test Loss: 0.0002
# Epoch 147/350, Train Loss: 0.0006, Test Loss: 0.0002
# Epoch 148/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 149/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 150/350, Train Loss: 0.0005, Test Loss: 0.0007
# Epoch 151/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 152/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 153/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 154/350, Train Loss: 0.0001, Test Loss: 0.0002
# Epoch 155/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 156/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 157/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 158/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 159/350, Train Loss: 0.0007, Test Loss: 0.0013
# Epoch 160/350, Train Loss: 0.0007, Test Loss: 0.0003
# Epoch 161/350, Train Loss: 0.0003, Test Loss: 0.0003
# Epoch 162/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 163/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 164/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 165/350, Train Loss: 0.0003, Test Loss: 0.0002
# Epoch 166/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 167/350, Train Loss: 0.0001, Test Loss: 0.0003
# Epoch 168/350, Train Loss: 0.0013, Test Loss: 0.0001
# Epoch 169/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 170/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 171/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 172/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 173/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 174/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 175/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 176/350, Train Loss: 0.0003, Test Loss: 0.0002
# Epoch 177/350, Train Loss: 0.0005, Test Loss: 0.0012
# Epoch 178/350, Train Loss: 0.0004, Test Loss: 0.0001
# Epoch 179/350, Train Loss: 0.0002, Test Loss: 0.0004
# Epoch 180/350, Train Loss: 0.0001, Test Loss: 0.0002
# Epoch 181/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 182/350, Train Loss: 0.0002, Test Loss: 0.0006
# Epoch 183/350, Train Loss: 0.0006, Test Loss: 0.0001
# Epoch 184/350, Train Loss: 0.0001, Test Loss: 0.0002
# Epoch 185/350, Train Loss: 0.0004, Test Loss: 0.0006
# Epoch 186/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 187/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 188/350, Train Loss: 0.0000, Test Loss: 0.0001
# Epoch 189/350, Train Loss: 0.0002, Test Loss: 0.0004
# Epoch 190/350, Train Loss: 0.0001, Test Loss: 0.0005
# Epoch 191/350, Train Loss: 0.0007, Test Loss: 0.0004
# Epoch 192/350, Train Loss: 0.0010, Test Loss: 0.0002
# Epoch 193/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 194/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 195/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 196/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 197/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 198/350, Train Loss: 0.0004, Test Loss: 0.0001
# Epoch 199/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 200/350, Train Loss: 0.0003, Test Loss: 0.0006
# Epoch 201/350, Train Loss: 0.0005, Test Loss: 0.0004
# Epoch 202/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 203/350, Train Loss: 0.0004, Test Loss: 0.0003
# Epoch 204/350, Train Loss: 0.0001, Test Loss: 0.0003
# Epoch 205/350, Train Loss: 0.0003, Test Loss: 0.0002
# Epoch 206/350, Train Loss: 0.0003, Test Loss: 0.0002
# Epoch 207/350, Train Loss: 0.0006, Test Loss: 0.0002
# Epoch 208/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 209/350, Train Loss: 0.0001, Test Loss: 0.0003
# Epoch 210/350, Train Loss: 0.0004, Test Loss: 0.0002
# Epoch 211/350, Train Loss: 0.0003, Test Loss: 0.0000
# Epoch 212/350, Train Loss: 0.0001, Test Loss: 0.0002
# Epoch 213/350, Train Loss: 0.0004, Test Loss: 0.0001
# Epoch 214/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 215/350, Train Loss: 0.0003, Test Loss: 0.0004
# Epoch 216/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 217/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 218/350, Train Loss: 0.0001, Test Loss: 0.0005
# Epoch 219/350, Train Loss: 0.0006, Test Loss: 0.0007
# Epoch 220/350, Train Loss: 0.0006, Test Loss: 0.0006
# Epoch 221/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 222/350, Train Loss: 0.0002, Test Loss: 0.0003
# Epoch 223/350, Train Loss: 0.0003, Test Loss: 0.0003
# Epoch 224/350, Train Loss: 0.0004, Test Loss: 0.0003
# Epoch 225/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 226/350, Train Loss: 0.0003, Test Loss: 0.0004
# Epoch 227/350, Train Loss: 0.0005, Test Loss: 0.0000
# Epoch 228/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 229/350, Train Loss: 0.0000, Test Loss: 0.0001
# Epoch 230/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 231/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 232/350, Train Loss: 0.0005, Test Loss: 0.0011
# Epoch 233/350, Train Loss: 0.0009, Test Loss: 0.0010
# Epoch 234/350, Train Loss: 0.0007, Test Loss: 0.0005
# Epoch 235/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 236/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 237/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 238/350, Train Loss: 0.0000, Test Loss: 0.0003
# Epoch 239/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 240/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 241/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 242/350, Train Loss: 0.0014, Test Loss: 0.0016
# Epoch 243/350, Train Loss: 0.0007, Test Loss: 0.0004
# Epoch 244/350, Train Loss: 0.0004, Test Loss: 0.0015
# Epoch 245/350, Train Loss: 0.0006, Test Loss: 0.0001
# Epoch 246/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 247/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 248/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 249/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 250/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 251/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 252/350, Train Loss: 0.0002, Test Loss: 0.0003
# Epoch 253/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 254/350, Train Loss: 0.0003, Test Loss: 0.0002
# Epoch 255/350, Train Loss: 0.0003, Test Loss: 0.0016
# Epoch 256/350, Train Loss: 0.0006, Test Loss: 0.0002
# Epoch 257/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 258/350, Train Loss: 0.0003, Test Loss: 0.0002
# Epoch 259/350, Train Loss: 0.0001, Test Loss: 0.0003
# Epoch 260/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 261/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 262/350, Train Loss: 0.0002, Test Loss: 0.0003
# Epoch 263/350, Train Loss: 0.0005, Test Loss: 0.0003
# Epoch 264/350, Train Loss: 0.0005, Test Loss: 0.0009
# Epoch 265/350, Train Loss: 0.0005, Test Loss: 0.0003
# Epoch 266/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 267/350, Train Loss: 0.0001, Test Loss: 0.0003
# Epoch 268/350, Train Loss: 0.0003, Test Loss: 0.0002
# Epoch 269/350, Train Loss: 0.0006, Test Loss: 0.0002
# Epoch 270/350, Train Loss: 0.0003, Test Loss: 0.0002
# Epoch 271/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 272/350, Train Loss: 0.0004, Test Loss: 0.0003
# Epoch 273/350, Train Loss: 0.0002, Test Loss: 0.0001
# Epoch 274/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 275/350, Train Loss: 0.0002, Test Loss: 0.0005
# Epoch 276/350, Train Loss: 0.0003, Test Loss: 0.0004
# Epoch 277/350, Train Loss: 0.0004, Test Loss: 0.0001
# Epoch 278/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 279/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 280/350, Train Loss: 0.0003, Test Loss: 0.0014
# Epoch 281/350, Train Loss: 0.0014, Test Loss: 0.0003
# Epoch 282/350, Train Loss: 0.0005, Test Loss: 0.0002
# Epoch 283/350, Train Loss: 0.0010, Test Loss: 0.0010
# Epoch 284/350, Train Loss: 0.0004, Test Loss: 0.0003
# Epoch 285/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 286/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 287/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 288/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 289/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 290/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 291/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 292/350, Train Loss: 0.0000, Test Loss: 0.0001
# Epoch 293/350, Train Loss: 0.0006, Test Loss: 0.0002
# Epoch 294/350, Train Loss: 0.0010, Test Loss: 0.0008
# Epoch 295/350, Train Loss: 0.0009, Test Loss: 0.0002
# Epoch 296/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 297/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 298/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 299/350, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 300/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 301/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 302/350, Train Loss: 0.0000, Test Loss: 0.0002
# Epoch 303/350, Train Loss: 0.0006, Test Loss: 0.0001
# Epoch 304/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 305/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 306/350, Train Loss: 0.0012, Test Loss: 0.0011
# Epoch 307/350, Train Loss: 0.0008, Test Loss: 0.0002
# Epoch 308/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 309/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 310/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 311/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 312/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 313/350, Train Loss: 0.0004, Test Loss: 0.0018
# Epoch 314/350, Train Loss: 0.0014, Test Loss: 0.0003
# Epoch 315/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 316/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 317/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 318/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 319/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 320/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 321/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 322/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 323/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 324/350, Train Loss: 0.0002, Test Loss: 0.0003
# Epoch 325/350, Train Loss: 0.0002, Test Loss: 0.0003
# Epoch 326/350, Train Loss: 0.0007, Test Loss: 0.0031
# Epoch 327/350, Train Loss: 0.0016, Test Loss: 0.0001
# Epoch 328/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 329/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 330/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 331/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 332/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 333/350, Train Loss: 0.0000, Test Loss: 0.0001
# Epoch 334/350, Train Loss: 0.0004, Test Loss: 0.0019
# Epoch 335/350, Train Loss: 0.0005, Test Loss: 0.0001
# Epoch 336/350, Train Loss: 0.0005, Test Loss: 0.0006
# Epoch 337/350, Train Loss: 0.0006, Test Loss: 0.0003
# Epoch 338/350, Train Loss: 0.0005, Test Loss: 0.0001
# Epoch 339/350, Train Loss: 0.0001, Test Loss: 0.0000
# Epoch 340/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 341/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 342/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 343/350, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 344/350, Train Loss: 0.0000, Test Loss: 0.0001
# Epoch 345/350, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 346/350, Train Loss: 0.0009, Test Loss: 0.0031
# Epoch 347/350, Train Loss: 0.0007, Test Loss: 0.0004
# Epoch 348/350, Train Loss: 0.0003, Test Loss: 0.0001
# Epoch 349/350, Train Loss: 0.0001, Test Loss: 0.0002
# Epoch 350/350, Train Loss: 0.0002, Test Loss: 0.0002

# %% [markdown]
# #Results

# %%
def pendulum_dynamics(x, u, params):  # Compute the function f(x,t) such that theta'' = f(x,t)
  theta, omega = x
  m, l, g = params["m"], params["l"], params["g"]
  u = float(u)

  d_theta = omega
  d_omega = (g/l) * np.sin(theta) + u/(m * l**2)

  return np.array([d_theta, d_omega])

def rk4_step(f, x, u, dt, params):  # Compute the position after a short time dt based on the pervious position using rk4 method
  k1 = f(x, u, params)
  k2 = f(x + 0.5 * dt * k1, u, params)
  k3 = f(x + 0.5 * dt * k2, u, params)
  k4 = f(x + dt * k3, u, params)

  return x + (dt/6)*(k1 + 2*k2 + 2*k3 + k4)

def trajectory_simulation(x0, u_control, dt, T, params):  # Compute the trajectory using rk4_step at each step
  N = int(T/dt)
  x = np.zeros((N+1, 2))
  x[0] = x0

  for t in range(N):
    u = u_control(t * dt, x[t])
    x[t+1] = rk4_step(pendulum_dynamics, x[t], u, dt, params)
  return x


def zero_control(t,x):
  return 0

def hamiltonian_dynamics_simulation(model, x):
    if x.dim() == 1:
        x = x.unsqueeze(0)

    theta = x[:,0]
    omega = x[:,1]

    X_tilde = torch.stack([torch.sin(theta), torch.cos(theta), omega], dim=1)
    X_tilde = X_tilde.requires_grad_(True)
    H = model(X_tilde).sum()

    grad = torch.autograd.grad(H, X_tilde, create_graph=True)[0]

    dH_dsin = grad[:,0]
    dH_dcos = grad[:,1]
    dH_dw   = grad[:,2]

    dH_dtheta = dH_dsin * torch.cos(theta) - dH_dcos * torch.sin(theta)

    dtheta = dH_dw
    domega = -dH_dtheta

    dx = torch.stack([dtheta, domega], dim=1)

    return dx.squeeze(0) if dx.shape[0] == 1 else dx


def rk4_step_HNN(f, x, dt):   # rk4_step but adapted for the HNN
    k1 = hamiltonian_dynamics_simulation(f, x)
    k2 = hamiltonian_dynamics_simulation(f, x + 0.5 * dt * k1)
    k3 = hamiltonian_dynamics_simulation(f, x + 0.5 * dt * k2)
    k4 = hamiltonian_dynamics_simulation(f, x + dt * k3)
    return x + (dt/6)*(k1 + 2*k2 + 2*k3 + k4)

def trajectory_simulation_HNN(x0, dt, T):  # adapted version for the HNN
    N = int(T / dt)
    x = torch.zeros((N+1, 2))
    x[0] = torch.tensor(x0, dtype=torch.float32)

    for t in range(N):
        x[t+1] = rk4_step_HNN(model, x[t], dt).detach()

    return x.detach().numpy()

def dH_dt(model, x):
    if x.dim() == 1:
        x = x.unsqueeze(0)

    theta = x[:, 0]
    omega = x[:, 1]

    X_tilde = torch.stack(
        [torch.sin(theta), torch.cos(theta), omega],
        dim=1
    ).requires_grad_(True)   # network input

    H = model(X_tilde).sum() # hamiltonian

    grad = torch.autograd.grad(H, X_tilde, create_graph=True)[0]

    dH_dsin = grad[:, 0]
    dH_dcos = grad[:, 1]
    dH_dω   = grad[:, 2]

    dH_dθ = dH_dsin * torch.cos(theta) - dH_dcos * torch.sin(theta) # chain rule

    dθ = dH_dω
    dω = -dH_dθ

    dHdt = dH_dθ * dθ + dH_dω * dω

    return dHdt.squeeze()


def mechanical_energy(x, params):    # Verification that Em is roughly constant
  m, l, g = params["m"], params["l"], params["g"]
  theta = x[:,0]
  omega = x[:,1]

  E = 0.5 * m * l**2 * omega**2 + m * g * l * np.cos(theta)
  return E

# %%
#--------------
# Parameters
#--------------

params = {
    "g": 9.81,   # gravity (m/s^2)
    "l": 1.0,    # lenght (m)
    "m": 1.0     # mass (kg)
}

x0 = [1.57, 0]

HNN_trajectory = []
true_trajectory = []
T = 5.0 # 5s
dt = 0.01 # 500 step

#--------------
# Trajectories
#--------------

HNN_trajectory = trajectory_simulation_HNN(x0, dt, T)

true_trajectory = trajectory_simulation(x0, zero_control, dt, T, params=params)

print( dH_dt(model, torch.tensor(x0, dtype=torch.float32)))

#-------
# Plot
#-------

t = np.arange(start=0, stop = 5.001, step = dt)

print(HNN_trajectory.shape)
print(true_trajectory.shape)
print(t.shape)

plt.plot(t, np.array(HNN_trajectory)[:,0], "--")
plt.plot(t, np.array(true_trajectory)[:,0])
plt.xlabel("Time (s)")
plt.ylabel("Theta (rad)")
plt.legend(["HNN", "True"])
plt.show()

plt.plot(t, np.array(HNN_trajectory)[:,1], "--")
plt.plot(t, np.array(true_trajectory)[:,1])
plt.xlabel("Time (s)")
plt.ylabel("Omega (rad/s)")
plt.legend(["HNN", "True"])
plt.show()

plt.figure()
plt.plot(np.array(HNN_trajectory)[:,0], np.array(HNN_trajectory)[:,1], "--")
plt.plot(np.array(true_trajectory)[:,0], np.array(true_trajectory)[:,1])
plt.legend(["HNN", "True"])
plt.xlabel("Theta (rad)")
plt.ylabel("Omega (rad/s)")
plt.show()
# Out:
# tensor(0., grad_fn=<SqueezeBackward0>)
# (501, 2)
# (501, 2)
# (501,)
